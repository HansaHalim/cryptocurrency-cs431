# %%
# Install Libraries
# !pip install textblob
# !pip install tweepy
# !pip install pycountry
# !pip install langdetect
# !pip install twython
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: textblob in /usr/local/lib/python3.9/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.9/site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.63.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2022.3.15)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/site-packages (from nltk>=3.1->textblob) (1.1.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: tweepy in /usr/local/lib/python3.9/site-packages (4.8.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /usr/local/lib/python3.9/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.9/site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.9/site-packages (from tweepy) (3.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: pycountry in /usr/local/lib/python3.9/site-packages (22.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from pycountry) (60.5.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: langdetect in /usr/local/lib/python3.9/site-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from langdetect) (1.15.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: twython in /usr/local/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.9/site-packages (from twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.9/site-packages (from twython) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.1.0->twython) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.1.0->twython) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests>=2.1.0->twython) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
from textblob import TextBlob
import sys
import tweepy
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
import os
import nltk
import pycountry
import re
import string
import json
import socket
# from wordcloud import WordCloud, STOPWORDS
# from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# from sklearn.feature_extraction.text import CountVectorizer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zacharytan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
from tweepy.streaming import Stream

class TweetsListener(Stream):
    def __init__(self, csocket):
        self.client_socket = csocket
    # we override the on_data() function in StreamListener
    def on_data(self, data):
        try:
            message = json.loads( data )
            print( message['text'].encode('utf-8') )
            self.client_socket.send( message['text'].encode('utf-8') )
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True

    def if_error(self, status):
        print(status)
        return True

# %%
def send_tweets(c_socket):
    auth = tweepy.auth.OAuthHandler(consumerKey, consumerSecret)
    auth.set_access_token(accessToken, accessTokenSecret)
    
    twitter_stream = tweepy.Stream(auth, TweetsListener(c_socket))
    twitter_stream.filter(track=['bitcoin'])

# %%
### Update tweets.csv

# import nltk
# nltk.download('vader_lexicon')

# keyword = "bitcoin"
# tweets = tweepy.Cursor(api.search_tweets, q=keyword).items()

# f = open("tweets.csv", "w")
# f.write("compound,created_at,retweet_count\n")

# for tweet in tweets:
#   if tweet.retweet_count < 100:
#     continue
    
#   score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
#   if score["compound"] == 0.0:
#     continue
    
#   f.write("{},{},{}\n".format(score["compound"],tweet.created_at,tweet.retweet_count))

# f.close()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zacharytan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <module>
#       7 f = open("test.txt", "w")
#       8 f.write("compound,created_at,retweet_count")
# ---> 10 for tweet in tweets:
#      11   if tweet.retweet_count < 100:
#      12     continue
#
# File /usr/local/lib/python3.9/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File /usr/local/lib/python3.9/site-packages/tweepy/cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File /usr/local/lib/python3.9/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File /usr/local/lib/python3.9/site-packages/tweepy/cursor.py:167, in IdIterator.next(self)
#     164     raise StopIteration
#     166 if self.index >= len(self.results) - 1:
# --> 167     data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     169     model = ModelParser().parse(
#     170         data, api = self.method.__self__,
#     171         payload_list=self.method.payload_list,
#     172         payload_type=self.method.payload_type
#     173     )
#     174     result = self.method.__self__.parser.parse(
#     175         data, api = self.method.__self__,
#     176         payload_list=self.method.payload_list,
#     177         payload_type=self.method.payload_type
#     178     )
#
# File /usr/local/lib/python3.9/site-packages/tweepy/api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/tweepy/api.py:1303, in API.search_tweets(self, q, **kwargs)
#    1209 @pagination(mode='id')
#    1210 @payload('search_results')
#    1211 def search_tweets(self, q, **kwargs):
#    1212     """search_tweets(q, *, geocode, lang, locale, result_type, count, \
#    1213                      until, since_id, max_id, include_entities)
#    1214
#    (...)
#    1301     .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1302     """
# -> 1303     return self.request(
#    1304         'GET', 'search/tweets', endpoint_parameters=(
#    1305             'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1306             'until', 'since_id', 'max_id', 'include_entities'
#    1307         ), q=q, **kwargs
#    1308     )
#
# File /usr/local/lib/python3.9/site-packages/tweepy/api.py:216, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     214 # Execute request
#     215 try:
# --> 216     resp = self.session.request(
#     217         method, url, params=params, headers=headers,
#     218         data=post_data, files=files, json=json_payload,
#     219         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220     )
#     221 except Exception as e:
#     222     raise TweepyException(f'Failed to send request: {e}').with_traceback(sys.exc_info()[2])
#
# File /usr/local/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File /usr/local/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import nltk
nltk.download('vader_lexicon')

#Sentiment Analysis
def percentage(part,whole):
 return 100 * float(part)/float(whole)

keyword = "bitcoin"
noOfTweet = 50
tweets = tweepy.Cursor(api.search, q=keyword).items(noOfTweet)
positive = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets: 
  # print(tweet)
  tweet_list.append(tweet.text)
  analysis = TextBlob(tweet.text)
  score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
  print(score)
  neg = score['neg']
  neu = score['neu']
  pos = score['pos']
  comp = score['compound']
  polarity += analysis.sentiment.polarity
 
  if neg > pos:
    negative_list.append(tweet.text)
    negative += 1
  elif pos > neg:
    positive_list.append(tweet.text)
    positive += 1
  elif pos == neg:
    neutral_list.append(tweet.text)
    neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.3384}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.101, 'neu': 0.671, 'pos': 0.228, 'compound': 0.4667}
# {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.25}
# {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.7332}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'compound': 0.128}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.097, 'neu': 0.789, 'pos': 0.114, 'compound': -0.1501}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.8402}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.5766}
# {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.7995}
# {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.6249}
# {'neg': 0.277, 'neu': 0.723, 'pos': 0.0, 'compound': -0.8057}
# {'neg': 0.096, 'neu': 0.904, 'pos': 0.0, 'compound': -0.2023}
# {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.4767}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.112, 'neu': 0.888, 'pos': 0.0, 'compound': -0.2263}
# {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
# {'neg': 0.0, 'neu': 0.77, 'pos': 0.23, 'compound': 0.6696}
# {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.129, 'neu': 0.759, 'pos': 0.112, 'compound': -0.1027}
# {'neg': 0.207, 'neu': 0.793, 'pos': 0.0, 'compound': -0.6696}

# %%
import nltk
nltk.download('vader_lexicon')

#Sentiment Analysis
def percentage(part,whole):
 return 100 * float(part)/float(whole)

keyword = "bitcoin"
noOfTweet = 50
tweets = ['This is the best day ever', 'bitcoin is going to the moon', 'I lost $5,000 because of bitcoin', 'thank you elon musk for new dog']
positive = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets: 
  print(tweet)
  tweet_list.append(tweet)
  analysis = TextBlob(tweet)
  score = SentimentIntensityAnalyzer().polarity_scores(tweet)
  print(score)
  neg = score['neg']
  neu = score['neu']
  pos = score['pos']
  comp = score['compound']
  polarity += analysis.sentiment.polarity
 
  if neg > pos:
    negative_list.append(tweet)
    negative += 1
  elif pos > neg:
    positive_list.append(tweet)
    positive += 1
  elif pos == neg:
    neutral_list.append(tweet)
    neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# This is the best day ever
# {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
# bitcoin is going to the moon
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# I lost $5,000 because of bitcoin
# {'neg': 0.365, 'neu': 0.635, 'pos': 0.0, 'compound': -0.3182}
# thank you elon musk for new dog
# {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'compound': 0.3612}

# %%
#Number of Tweets (Total, Positive, Negative, Neutral)
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print("total number: ",len(tweet_list))
print("positive number: ",len(positive_list))
print("negative number: ", len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  50
# positive number:  23
# negative number:  6
# neutral number:  21

# %%
tweet_list
# Out:
#                                                     0
# 0   RT @Jayecane: I badly need to send 8 people mo...
# 1   RT @Jayecane: I badly need to send 8 people mo...
# 2   @MichellePhan @CashApp $RBaiZa #Bitcoin #bitco...
# 3   RT @Jayecane: I badly need to send 8 people mo...
# 4   RT @Coinimparator: #Coinimparator ve ailesi yi...
# 5   RT @Jayecane: I badly need to send 8 people mo...
# 6   Bitcoin and Gold have gone up a bit, #xrp has ...
# 7   RT @loopstarter: Take the power of the collect...
# 8   The strongest bullish signal has broken out fo...
# 9   Now that I agree with #Bitcoin you can’t chang...
# 10  @MrBigWhaleREAL @bbtc Vitteey MEXC Don't Miss ...
# 11  RT @BitcoinMagazine: NEW - U.S. Senate Candida...
# 12  @MichellePhan @CashApp $Myknikes19 #BitcoinPle...
# 13  RT @naiivememe: @saylor @SecYellen #Bitcoin ht...
# 14  RT @rovercrc: #BITCOIN TO $50,000 THIS WEEK, O...
# 15  RT @CakirbeyNusret: 💥Arkadaşlar Kar Realize Et...
# 16  RT @MitchRayTA: #ATOM "Moon soon" variables fu...
# 17  RT @BscPitbull: Metrics are on the moon🌙 #Pitb...
# 18  RT @healthy_pockets: Simplemente #Bitcoin \n\n...
# 19  @WendyRogersAZ Did you do your own research ab...
# 20  RT @stanmilc: 📲@CryptoHawkAI Long-Short: \n\n🚨...
# 21  RT @BBCWorld: Russia considers accepting Bitco...
# 22  @stevedabitcoin aynen abi bitcoin marsa falan ...
# 23  RT @Jayecane: I badly need to send 8 people mo...
# 24  @MichellePhan @CashApp $jennmoney17 #bitcoinpl...
# 25  RT @ksknkripto: Ayı kardeşler bi kalkın birşey...
# 26  RT @DocumentingBTC: In 8 days, the 19,000,000t...
# 27  RT @Jayecane: I badly need to send 8 people mo...
# 28  RT @DWhitmanBTC: Opt out of this giant Ponzi \...
# 29  RT @MichellePhan: I’ve teamed up with @cashapp...
# 30  @MichellePhan @CashApp $ZynnyZyn #bitcoinpleas...
# 31  RT @MichellePhan: I’ve teamed up with @cashapp...
# 32  RT @Crypto_Airport: @CoinMarketCap Comeeee onn...
# 33  RT @Arthur_van_Pelt: BREAKING: \n\nBitcoin dev...
# 34  @nftjuno https://t.co/V60nwJE1nL \n\n#NFTCommu...
# 35  RT @portal_finance: 🔥 The #Portal project is a...
# 36  RT @CoinLejyon: #Bitcoin ile birlikte #Btc dom...
# 37  @MichellePhan @CashApp $BigBeast69 #Bitcoin #b...
# 38  RT @DenevaAni: JUST IN: Bitcoin of America has...
# 39  RT @ReiRubroNegro: @leandroruschel @elonmusk E...
# 40  RT @RicardoBSalinas: Muchas gracias por tan am...
# 41  @nypost I never thought of meeting a legit bit...
# 42  Rusya, petrol ve gaz satışını Bitcoin ile sağl...
# 43  @MichellePhan @CashApp $btejeda #bitcoinplease...
# 44  4.) You can trustlessly earn yield through sta...
# 45  RT @ramiberlin: @realSologenic @xrpstik #xSTIK...
# 46  RT @westkripto: #Stepn’den ettiğim kârı bugün ...
# 47  🤣 Canada way ahead of Russia on this one #Bitc...
# 48  Come in now and don't BE LATE #xrp #bitcoin #c...
# 49  RT @theKriptolik: ⚡️ ÇEKİLİŞ ⚡️\n\n💰10 kişiye ...

# %%
api.search()
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-9-25a02992b3c4> in <module>()
# ----> 1 api.search()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: [{'code': 25, 'message': 'Query parameters are missing.'}]

# %%
for tweet in tweets:
 print(tweet.text)
# Out:
# RT @PolandYielder: TUSD is coming to Yield App🚀🚀🚀💎💎💎
# Earn up to 14% p.a. 💪💪💪🪙🪙🪙📈📈📈
# https://t.co/F1OBcHuym3
# @YieldApp @YieldAppPoland #yield…
# RT @Stray_cats_BSV: #StrayCats =
# @Biarritz82 +
# @LCarrion80 aka @BlogueroDigital;
# quienes además
# de compartir vida, compartimos
# pasiones com…
# RT @ParaBorsaCrypto: Endeksler ve #Bitcoin 'de hareketlilik başladı.
# RT @AirDropTR_EN: 🔥HEDIYE  ZAMANI 🌟
#
# 3 KİŞİYE 250'₺ TOPLAM 750'₺
#
#  RT yap
#
# Takip et
#
# Süre Cumartesi 21.00 ⏳kadar
#
# Bol şans dostlar.
#
# #BTC …
# RT @gladstein: “Decentralizing both finance and the internet would offer a long-overdue counterweight to the very concentrated power and we…
# RT @LeCoinBit: Instead of predicting, try ENGAGING.
#
# The world is depressing when you’re not part of it. Try person… https://t.co/Ynv4zxHwf6
# RT @zam_zach711: ALL PRICES ARE BACK TO $50.00 STARTING TODAY (MARCH 10-)!
# #GospelMusic #BTC #crytocurrency #Coinbase #cashapp #ETH #Crypto…
# 🇺🇸 USD: $40,826
# 🇪🇺 EUR: €36,689
# 🇬🇧 GBP: £30,976
# 🇨🇦 CAD: $51,605
# 🇦🇺 AUD: $55,365
# 🇯🇵 JPY:  ¥4,839,844
#
#  #Bitcoin #BTC
# This book on #Bitcoin  by our friend and human right activist
#
# Can’t wait to read it.
# Get your copy now 👇… https://t.co/aA4A3GMrYM
# @Cointelegraph @Metamoonft 🚀🚀🚀
# #metamoonnft #Metaverse #NFTs #BSCGem #BinanceSmartChain #Binance  #bitcoin  #ETH
#
# https://t.co/6aOurTwhkB
# RT @Cryptohelinn: 1 kişiye bu değerli nft' yi hediye ediyorum.
#
# Değeri 40$ ile 100$ arasında
#
# 🎁  Bu paylaşımı beğen❤
#
# 🎁 @cryptohelinn hesab…
# RT @KriptoErdems: RT yapan ve bizi takip eden 5 kişiye 100$ verelim..
#
# 150 RT olduğu gibi açıklıyorum, yeni gelmedik geri geldik!
#
# #bitcoin…
# RT @CryptoDogg7: Toplam 100 TL Nakit !
# 2 kişiye 50 + 50 olacak şekilde.
# 👉 Like ❤️👈
# 👉 RT ♻️ 👈
# 👉 Takip 👈
# Çekiliş sonuç tarihi  👉 18.03.2022…
# RT @Cryptohelinn: 1 kişiye bu değerli nft' yi hediye ediyorum.
#
# Değeri 40$ ile 100$ arasında
#
# 🎁  Bu paylaşımı beğen❤
#
# 🎁 @cryptohelinn hesab…
# https://t.co/p9uxg4dovB
# Mining bitcoin
# @obs_bitcoin @ChaincodeLabs I’m not turning any off, just playing with under/over clocking while I collect data on battery bank.
# Satoshi Nakamoto is the creator of Bitcoin. #BitcoinButton #Binance https://t.co/rMVi3KOTBZ
# RT @realSologenic: We are thrilled to announce that the Sologenic team will be participating in Miami’s #Bitcoin Month!
#
# The team will be a…
# The economic cycle designed by Bitcoin is closer to the US government's dollar monetary policy, which is also basic… https://t.co/9GY3CZCbIt
# Bitcoin Discussion https://t.co/kWaLWH6nz8
# RT @Negentropic_: #Bitcoin 's fundamentals show resilience in a charged macro environment as long-term holders accumulate,
# and capital is m…
# RT @PolandYielder: The mobile application for @YieldApp  has just started testing! 💪💎🚀💪💎🚀💪💎🚀
#
# Bank in your pocket - literally! 💎💪🚀
#
# https:/…
# RT @BitcoinMagazine: "We need #bitcoin to be legal tender in Mexico." - Mexican senator 🇲🇽 https://t.co/2uY225IcrZ
# @BillyM2k https://t.co/gcRIMIvQin #PolygonNFTs #altcoin #art #SOL #dogecoin #DogecoinArmy #Polygon #Crypto… https://t.co/Dx5t7fOT7S
# RT @BitcoinMagazine: Senator Pat Toomey to the senate: Ukraine has actively been using #bitcoin and crypto to do tremendous good. 🇺🇦 https:…
# RT @BitcoinMagazine: Senator Pat Toomey to the senate: Ukraine has actively been using #bitcoin and crypto to do tremendous good. 🇺🇦 https:…
# RT @CryptoLopez5: El futuro #Bitcoin  ha llegado  #BitcoinButton and #Binance https://t.co/4Se20MHSBP
# RT @blocktrainer: Wie Proof of Work bzw. #Bitcoin Mining technisch funktioniert, erklärt euch der liebe Danny von @OrangeRelation auf dem #…
# RT @Dennis_Porter_: Time to call your elected officials to oppose the anti-Bitcoin bill that @ewarren introduced this morning!
#
# Use the lin…
# HSBC banned the purchase of 'risky' crypto for ordinary account holders in the UK last year to 'protect them'… https://t.co/2QK4dLGGjg
# RT @Negentropic_: #Bitcoin 's fundamentals show resilience in a charged macro environment as long-term holders accumulate,
# and capital is m…
# #DeFi #TeleFy #DEX #cryptocurrency #Ethereum #BinanceSmartChain #Bitcoin
# #Airdrop #Polkadot #MATIC $TELE #Cardano… https://t.co/XjVmp5pRJQ
# @binance @apecoin @Metamoonft 🚀🚀🚀
# #metamoonnft #Metaverse #NFTs #BSCGem #BinanceSmartChain #Binance  #bitcoin  #ETH
#
# https://t.co/6aOurTwhkB
# @Elypse2021 https://t.co/gcRIMIvQin #PolygonNFTs #altcoin #art #SOL #dogecoin #DogecoinArmy #Polygon #Crypto… https://t.co/6whL6uIEJF
# @PeterSchiff Sell some #Bitcoin Peter! Or you can stake some Mad Meerkats and pay for the studio from the yield https://t.co/3q61sIBnuv
# Mirror World how to use AI + GameFi to create Web3 nintendo?… https://t.co/421o5B6yki
# @MoonOverlord nah. bitcoin cash
# RT @TurkishGiveaway: Yeni Çekiliş 🎉
# Ülkemiz Adına Önemli Bir Maça Çıkacak Olan Galatasaray Kazanırsa Bir Arkadaşımıza 250 TL Değerinde #GAL…
# RT @BitcoinMagazine: Senator Pat Toomey to the senate: Ukraine has actively been using #bitcoin and crypto to do tremendous good. 🇺🇦 https:…
# RT @blocktrainer: Wie Proof of Work bzw. #Bitcoin Mining technisch funktioniert, erklärt euch der liebe Danny von @OrangeRelation auf dem #…
# GMT/USDT SHORT 🛑
# Leverage 20x
# Entries 0.720
# Target 1 0.709
# Target 2 0.691
# Target 3 0.666
# Target 4 0.600
# Target 5 0.… https://t.co/4Qkn0SbM0u
# @TrustNodes https://t.co/q5jnJYSiRN
# If you still trying to decide to buy #Bitcoin. Do it today. Do it now.
# RT @Dennis_Porter_: Time to call your elected officials to oppose the anti-Bitcoin bill that @ewarren introduced this morning!
#
# Use the lin…
# #talks
#
# 👑johnny
# CryptoGodJohn:
# If we can clear this level I am expecting a move towards .075
# Telegram Channel = Cry… https://t.co/ywJjg5eqSH
# @SenDuckworth You need an opinion on #bitcoin. Please do not let Illinois lose out again to other states which embr… https://t.co/1rKQZMnbrZ
# @_NFTsArt @cybotz_nft https://t.co/gcRIMIvQin #PolygonNFTs #altcoin #art #SOL #dogecoin #DogecoinArmy #Polygon… https://t.co/zUe5tXqQhi
# RT @MatthewHyland_: #Bitcoin Weekly MACD Bull cross is looming: https://t.co/dPXviNWb1A
# 17.03.2022|https://t.co/IULzdDGMJD: IQ Labs CEO Tom Tirman on Unlocking Utility for NTFs With Collateral-Less Renti… https://t.co/bw7uXp8V8A
# RT @MartyBent: Rabbit Hole Recap rip 191 is live! @ODELL and I are back in person in the Bitcoin Commons discussing data leaks, chain surve…

# %%
# !apt-get update -qq > /dev/null
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-2.4.8/spark-2.4.8-bin-hadoop2.7.tgz
# !tar xf spark-2.4.8-bin-hadoop2.7.tgz
# !pip install -q findspark
# !wget -q https://student.cs.uwaterloo.ca/~cs451/content/cs431/sql-data.tgz
# !tar -xzf sql-data.tgz

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.8-bin-hadoop2.7"

import findspark
findspark.init()

from pyspark.sql import SparkSession
import random

spark = SparkSession.builder.appName("YourTest").master("local[2]").config('spark.ui.port', random.randrange(4000,5000)).getOrCreate()

# %%
nation_raw = spark.read.csv("nation.tbl",sep='|',inferSchema=True)
nation_raw.show()
